# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.size'] = 14
mpl.rcParams['lines.linewidth'] = 3
mpl.rcParams['axes.titlesize'] = 18
mpl.rcParams['axes.grid'] = True
mpl.rcParams['grid.alpha'] = 0.5
mpl.rcParams['figure.figsize'] = 10,6

import tensorflow as tf
from tensorflow.keras.models import load_model
import tensorflow.keras as K

from utilities.dataset.load_files import get_file_lists
from utilities.dataset.make_dataset import make_dataset

# %%
# # Load in the data
# data_directory = "/home/tye/data/numpy/fake/data1002/"
# X = np.load(data_directory + "test/X_noisy_library_pulse_r0.npy")
# Y = np.load(data_directory + "test/y_clean_library_pulse_r0.npy")

# %%
# Load in all test data
data_directory = "/home/tye/data/numpy/fake/data1002/"
file_lists = get_file_lists(data_directory)
list_X_test, list_Y_test = file_lists['test']

# %%
X = np.array([np.load(fname) for fname in list_X_test])
X = X.reshape(8650,4096)

Y = np.array([np.load(fname) for fname in list_Y_test])
Y = Y.reshape(8650,4096)

# %%
gen_n2c = load_model("saved_models/exp_19/generator_n2c_19", custom_objects={'tf': tf})
gen_c2n = load_model("saved_models/exp_19/generator_c2n_19", custom_objects={'tf': tf})
# Out:
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/keras/layers/core.py:1059: UserWarning: networks.generator is not loaded, but a Lambda layer uses it. It may cause errors.
#   warnings.warn('{} is not loaded, but a Lambda layer uses it. '
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
D = gen_n2c.predict(X)

# %%
#exp 19
i = 1

plt.plot(X[i], label="Noisy Pulse")
plt.plot(Y[i], label="Clean Pulse")
plt.plot(D[i], label="Noise Removed Pulse")

plt.ylabel("Arbitrary Units")
plt.xlabel("Event Samples")
plt.legend()
plt.show()

# %%
#exp 18
i = 1

plt.plot(X[i], label="Noisy Pulse")
plt.plot(Y[i], label="Clean Pulse")
plt.plot(D[i], label="Noise Removed Pulse")

plt.ylabel("Arbitrary Units")
plt.xlabel("Event Samples")
plt.legend()
# plt.show()
plt.savefig('n2c_exp_18.png')

# %%
#exp 12
i = 1

plt.plot(X[i], label="Noisy Pulse")
plt.plot(Y[i], label="Clean Pulse")
plt.plot(D[i], label="Noise Removed Pulse")

plt.ylabel("Arbitrary Units")
plt.xlabel("Event Samples")
plt.legend()
plt.show()

# %%
#exp 11
i = 1

plt.plot(X[i], label="Noisy Pulse")
plt.plot(Y[i], label="Clean Pulse")
plt.plot(D[i], label="Noise Removed Pulse")

plt.ylabel("Arbitrary Units")
plt.xlabel("Event Samples")
plt.legend()
plt.show()

# %%
#exp 10
i = 1

plt.plot(X[i], label="Noisy Pulse")
plt.plot(Y[i], label="Clean Pulse")
plt.plot(D[i], label="Noise Removed Pulse")

plt.ylabel("Arbitrary Units")
plt.xlabel("Event Samples")
plt.legend()
plt.show()

# %%
#exp 5
i = 1

plt.plot(X[i], label="Noisy Pulse")
plt.plot(Y[i], label="Clean Pulse")
plt.plot(D[i], label="Noise Removed Pulse")

plt.ylabel("Arbitrary Units")
plt.xlabel("Event Samples")
plt.legend()
plt.show()

# %%
#exp 9
i = 100

plt.plot(X[i], label="Noisy Pulse")
plt.plot(Y[i], label="Clean Pulse")
plt.plot(D[i], label="Noise Removed Pulse")

plt.ylabel("Arbitrary Units")
plt.xlabel("Event Samples")
plt.legend()
plt.show()

# %%
#exp 8
i = 1

plt.plot(X[i], label="Noisy Pulse")
plt.plot(Y[i], label="Clean Pulse")
plt.plot(D[i], label="Noise Removed Pulse")

plt.ylabel("Arbitrary Units")
plt.xlabel("Event Samples")
plt.legend()
plt.show()

# %%
#exp 6
i = 1

plt.plot(X[i], label="Noisy Pulse")
plt.plot(Y[i], label="Clean Pulse")
plt.plot(D[i], label="Noise Removed Pulse")

plt.ylabel("Arbitrary Units")
plt.xlabel("Event Samples")
plt.legend()
plt.show()

# %%
#exp 7
i = 1

plt.plot(X[i], label="Noisy Pulse")
plt.plot(Y[i], label="Clean Pulse")
plt.plot(D[i], label="Noise Removed Pulse")

plt.ylabel("Arbitrary Units")
plt.xlabel("Event Samples")
plt.legend()
plt.show()
