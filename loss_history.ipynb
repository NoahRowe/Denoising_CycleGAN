# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open("saved_models/lossses.pkl", "rb") as f: 
    losses = pickle.load(f)

# %%
gen_n2c_loss = [x.numpy() for x in losses['gen_n2c_loss']]
gen_c2n_loss = [x.numpy() for x in losses['gen_c2n_loss']]
disc_n_loss = [x.numpy() for x in losses['disc_n_loss']]
disc_c_loss = [x.numpy() for x in losses['disc_c_loss']]

# %%
plt.plot(gen_n2c_loss)
plt.plot(gen_c2n_loss)
plt.plot(disc_n_loss)
plt.plot(disc_c_loss)
